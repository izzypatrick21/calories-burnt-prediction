# %% [markdown]
# # Project: Calories Burnt Prediction

# %% [markdown]
# Intro: This project aims at predicting the calories burnt, body type and exercise.
# Data is gotten from kaggle - https://www.kaggle.com/fmendes/fmendesdat263xdemos

# %%
Import Libr

# %% [markdown]
# # Data Import and Inspection

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Data Analysis

# %% [markdown]
# # Train Test Split

# %% [markdown]
# # Model Selection and Training

# %% [markdown]
# # Model Evaluation on Test Data

# %% [markdown]
# # Plotting Actual and Predicted Test Data
